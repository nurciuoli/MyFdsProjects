# %%
import qe.myqengine as qe
import pandas as pd

# %%
univ = qe.ScreenUniverse('FG_CONSTITUENTS(SP50,0,CLOSE)=1')
ts = qe.TimeSeries(start_date='0Y',end_date = '0Y')
df = qe.calculate(universe = univ, dates =ts,formulas = ['FREF_MARKET_VALUE_COMPANY(1,USD,1)',
                                                         'P_PRICE_RETURNS(1,0,+1/0/0,USD)',
                                                         'QFL_RBICS_CLASS(0,SECT)',
                                                         'QFL_FCFY(0,CT)',
                                                         'QFL_DY(0,CT)',
                                                         'QFL_OCFY(0,CT)',
                                                         'QFL_CFROIC(0,CT)',
                                                         'QFL_RES_RET_MOM(0,252D)']).data
df
# Out:
#          DATE UNIVERSE  FREF_MARKET_VALUE_COMPANY(1,USD,1)  \
# 0    20221230     CTAS                        45667.319579
# 1    20221230      RTX                       148196.824753
# 2    20221230      WEC                        29701.317422
# 3    20221230      MAA                        18439.330973
# 4    20221230      AES                        18776.068388
# ..        ...      ...                                 ...
# 498  20221230     PARA                        11193.751497
# 499  20221230     CARR                        34796.840469
# 500  20221230     OTIS                        32960.290177
# 501  20221230     MTCH                        11468.308493
# 502  20221230      WBD                        23166.897710
#
#      P_PRICE_RETURNS(1,0,+1/0/0,USD) QFL_RBICS_CLASS(0,SECT)  QFL_FCFY(0,CT)  \
# 0                          -1.744830                    1010        2.763833
# 1                          -1.060250                    4010        2.217081
# ...
