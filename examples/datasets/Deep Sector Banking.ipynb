# %%
import qe.myqengine as qe
import pandas as pd

# %%
univ = qe.ScreenUniverse(universe_expr='ZAV(FB_ASSETS(ANN,0,RF))>0')
data_dict = {"is_lg_flag":'IF(FB_IS_LG_BHC(QTR),PROPER("YES"),PROPER("NO"))',
             "assets_q":"FB_ASSETS(QTR,0,RF)",
             "roe":'FB_ROE(QTR,0,RF,LOCAL,"")',
             'int_mgn':'FB_INT_MGN(QTR,0,RF,LOCAL,"")',
             'eff_ration':'FB_EFF_RATIO(QTR,0,RF)',
             'non_perf_assets_pct':'FB_ASSETS_NONPERF_PCT(QTR,0,RF)',
             'eq_assets':'FB_EQ_ASSETS(QTR,0,RF)',
             'loan_deps': 'FB_LOAN_DEPS(QTR,0,RF)'
             }
calc = qe.Calculation(universe=univ,dates = qe.TimeSeries(start_date = '0'),data_dict=data_dict)
calc.query()
calc.data
# Out:
#           DATE  UNIVERSE is_lg_flag   assets_q        roe   int_mgn  \
# 0     20230831      BANF        Yes  12020.440  17.812962  3.836423
# 1     20230831      FCBC        Yes   3391.437  10.369288  4.195442
# 2     20230831       NBN       None   2869.938  16.215889  5.534964
# 3     20230831      FULT        Yes  27356.418  11.758599  3.594670
# 4     20230831       FBP        Yes  19152.455  19.562809  4.407183
# ...        ...       ...        ...        ...        ...       ...
# 6016  20230831  0VYNQH-E        Yes    131.112   4.239799  3.974378
# 6017  20230831  0VYNRD-E       None    128.376        NaN       NaN
# 6018  20230831  0VYP08-E       None     15.664  15.291010  2.673294
# 6019  20230831  0VYPRL-E       None     71.318 -14.382109  4.054674
# 6020  20230831  0VYQ90-E       None    125.919        NaN       NaN
#
#       eff_ration  non_perf_assets_pct  eq_assets   loan_deps
# 0      53.220969             0.566668  11.154259   69.759147
# ...
