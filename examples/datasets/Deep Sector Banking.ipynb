# %%
import qe.myqengine as qe
import pandas as pd

# %%
univ = qe.ScreenUniverse(universe_expr='ZAV(FB_ASSETS(ANN,0,RF))>0')
df = qe.calculate(universe=univ,dates = qe.TimeSeries(start_date = '0'),formulas =['IF(FB_IS_LG_BHC(QTR),PROPER("YES"),PROPER("NO"))',
                                                                                   'FB_ASSETS(QTR,0,RF)',
                                                                                   'FB_ROE(QTR,0,RF,LOCAL,"")',
                                                                                   'FB_INT_MGN(QTR,0,RF,LOCAL,"")',
                                                                                   'FB_EFF_RATIO(QTR,0,RF)',
                                                                                   'FB_ASSETS_NONPERF_PCT(QTR,0,RF)',
                                                                                   'FB_EQ_ASSETS(QTR,0,RF)',
                                                                                   'FB_LOAN_DEPS(QTR,0,RF)']).data
df
# Out:
#           DATE  UNIVERSE IF(FB_IS_LG_BHC(QTR),PROPER("YES"),PROPER("NO"))  \
# 0     20230831      BANF                                              Yes
# 1     20230831      FCBC                                              Yes
# 2     20230831       NBN                                             None
# 3     20230831      FULT                                              Yes
# 4     20230831       FBP                                              Yes
# ...        ...       ...                                              ...
# 6017  20230831  0VYNQH-E                                              Yes
# 6018  20230831  0VYNRD-E                                             None
# 6019  20230831  0VYP08-E                                             None
# 6020  20230831  0VYPRL-E                                             None
# 6021  20230831  0VYQ90-E                                             None
#
#       FB_ASSETS(QTR,0,RF)  FB_ROE(QTR,0,RF,LOCAL,"")  \
# ...
