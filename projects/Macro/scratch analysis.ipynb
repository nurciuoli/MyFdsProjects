# %%
import pandas as pd
df = pd.read_csv('union_strike_search_results.csv').set_index('Date')
df
# Out:
#            Filings  News  Press Releases  Transcripts  Research  \
# Date
# 01-Jan'96        4     0               0            0         0
# 01-Jan'97       58     0               0            0         0
# 01-Jan'98       85     0               0            0         0
# 01-Jan'99       76     0               0            0         0
# 01-Jan'00       39     0               0            0         0
# 01-Jan'01       69     0               0            0         0
# 01-Jan'02       78     8               0            0         0
# 01-Jan'03       98     6               0            5         0
# 01-Jan'04      153    10               0            5         0
# 01-Jan'05      126    45               0            1         0
# 01-Jan'06      186    76               1            6         0
# 01-Jan'07      215    18               0            3         0
# 01-Jan'08      229    28               1            4         0
# 01-Jan'09      199     7               0            3         8
# ...

# %%
df.plot(figsize = (15,10))
# Out:
# <Axes: xlabel='Date'>

# %%
df.pct_change().plot(figsize = (15,10))
# Out:
# <Axes: xlabel='Date'>
